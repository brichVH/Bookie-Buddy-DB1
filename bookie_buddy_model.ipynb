# %%
library()

# %%
install.packages("zoo")
install.packages("hoopR")
install.packages("kernlab")
install.packages("tidymodels")
install.packages("AzureStor")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘globals’, ‘listenv’, ‘parallelly’, ‘snakecase’, ‘furrr’, ‘future’, ‘janitor’, ‘progressr’, ‘Rcpp’, ‘RcppParallel’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘future.apply’, ‘numDeriv’, ‘SQUAREM’, ‘lava’, ‘prodlim’, ‘warp’, ‘iterators’, ‘lhs’, ‘DiceDesign’, ‘patchwork’, ‘clock’, ‘gower’, ‘ipred’, ‘timeDate’, ‘slider’, ‘foreach’, ‘GPfit’, ‘modelenv’, ‘conflicted’, ‘dials’, ‘hardhat’, ‘infer’, ‘modeldata’, ‘parsnip’, ‘recipes’, ‘rsample’, ‘tune’, ‘workflows’, ‘workflowsets’, ‘yardstick’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘jose’, ‘AzureGraph’, ‘AzureAuth’, ‘AzureRMR’

# %%
library(tidyverse)
library(zoo)
library(hoopR)
library(tidymodels)
library(kernlab)
library(AzureStor)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.4.1     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.1
# ✔ tidyr   1.3.0     ✔ stringr 1.4.1
# ✔ readr   2.1.4     ✔ forcats 1.0.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ broom        1.0.4     ✔ rsample      1.1.1
# ✔ dials        1.1.0     ✔ tune         1.0.1
# ✔ infer        1.0.4     ✔ workflows    1.1.3
# ✔ modeldata    1.1.0     ✔ workflowsets 1.0.0
# ✔ parsnip      1.0.4     ✔ yardstick    1.1.0
# ✔ recipes      1.0.5
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Dig deeper into tidy modeling with R at https://www.tmwr.org
#
#
# Attaching package: ‘kernlab’
#
#
# The following object is masked from ‘package:scales’:
#
#     alpha
#
#
# The following object is masked from ‘package:purrr’:
#
#     cross
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     alpha

# %%
set.seed(1234)

# %%
kenpom <- read_csv("kenpom_2023.csv")
namekey <- read_csv("http://mattwaite.github.io/sportsdatafiles/nametable.csv")
simplestats <- read_csv("simplestats.csv")
# Out:
# New names:
# • `` -> `...1`
# Rows: 4223 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): TeamName
# dbl (8): ...1, Season, adj_o, adj_d, adj_tempo, luck, sos_adj_o, sos_adj_d
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 358 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): team_short_display_name, team, School
# dbl (1): team_id
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 3185 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): School
# dbl (3): Season, OverallSOS, OverallSRS
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
head(filter(kenpom, Season==2018))
# Out:
#   ...1 Season TeamName       adj_o adj_d adj_tempo luck   sos_adj_o sos_adj_d
# 1 0    2018   Virginia       116.4 84.3  59.4       0.032 110.9     100.9
# 2 1    2018   Villanova      127.4 95.9  68.5      -0.018 111.2     100.9
# 3 2    2018   Duke           122.5 93.4  70.3      -0.029 110.9     100.0
# 4 3    2018   Cincinnati     113.6 86.4  65.1      -0.015 106.6     104.0
# 5 4    2018   Purdue         123.2 96.5  67.5       0.003 109.3     100.7
# 6 5    2018   Michigan State 119.9 93.6  67.4       0.048 109.0     102.5

# %%
head(namekey)
# Out:
#   team_short_display_name team_id team              School
# 1 Abilene Chrstn          2000    Abilene Christian Abilene Christian
# 2 Air Force               2005    Air Force         Air Force
# 3 Akron                   2006    Akron             Akron
# 4 Alabama                  333    Alabama           Alabama
# 5 Alabama A&M             2010    Alabama A&M       Alabama A&M
# 6 Alabama State           2011    Alabama St.       Alabama State

# %%
head(simplestats)
# Out:
#   School             Season OverallSOS OverallSRS
# 1 Abilene Christian  2015    -6.34     -17.20
# 2 Air Force          2015    -0.71      -1.85
# 3 Akron              2015    -0.47       3.65
# 4 Alabama A&M        2015    -9.62     -17.15
# 5 Alabama-Birmingham 2015     1.62       1.94
# 6 Alabama State      2015   -12.71      -8.97

# %%
years = c(2018,2019,2021,2022,2023)
teamgames <- load_mbb_team_box(seasons = years) 
teamgames <- teamgames %>%
  mutate(team_short_display_name = ifelse(team_short_display_name=="Kansas St" & season>2021, "Kansas State", team_short_display_name)) %>%
  mutate(team_short_display_name = ifelse(team_short_display_name=="San Diego St" & season>2021, "San Diego State", team_short_display_name)) %>%
  mutate(team_short_display_name = ifelse(team_short_display_name=="Michigan St" & season>2021, "Michigan State", team_short_display_name))

head(select(filter(filter(teamgames, season>=2022), team_short_display_name=="San Diego St"), team_short_display_name), n=50)
teamgames <- teamgames %>%
  
  separate(field_goals_made_field_goals_attempted, into = c("field_goals_made","field_goals_attempted")) %>%
  separate(three_point_field_goals_made_three_point_field_goals_attempted, into = c("three_point_field_goals_made","three_point_field_goals_attempted")) %>%
  separate(free_throws_made_free_throws_attempted, into = c("free_throws_made","free_throws_attempted")) %>%
  mutate_at(12:34, as.numeric) %>% 
  mutate(team_id = as.numeric(team_id))

  teamgames <- teamgames %>% left_join(namekey) %>% 
    left_join(kenpom, by=c("team_short_display_name" = "TeamName", "season" = "Season")) %>% 
    left_join(simplestats, by=c("School" = "School", "season" = "Season"))  
  #teamgames <- teamgames %>% left_join(namekey) %>% left_join(kenpom, by=c("team" = "team", "season"="year")) %>% left_join(simplestats, by=c("School" = "School", "season" = "Season"))
  #summary(teamgames)
# Out:
#      team_short_display_name
# Joining with `by = join_by(team_short_display_name, team_id)`

# %%
 summary(teamgames)
#select(filter(teamgames, is.na(sos_adj_d)),team_short_display_name,team, School, season)
# Out:
#  team_short_display_name   team_uid         team_alternate_color
#  Length:56450            Length:56450       Length:56450
#  Class :character        Class :character   Class :character
#  Mode  :character        Mode  :character   Mode  :character
#
#
#
#
#   team_color        team_display_name   team_name          team_logo
#  Length:56450       Length:56450       Length:56450       Length:56450
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#  team_location         team_id       team_abbreviation   team_slug
#  Length:56450       Min.   :     1   Length:56450       Length:56450
#  Class :character   1st Qu.:   197   Class :character   Class :character
#  Mode  :character   Median :  2083   Mode  :character   Mode  :character
#                     Mean   :  2361
#                     3rd Qu.:  2466
#                     Max.   :127162
#
#  field_goals_made field_goals_attempted field_goal_pct
#  Min.   : 6.00    Min.   : 26.00        Min.   :12.20
#  1st Qu.:22.00    1st Qu.: 53.00        1st Qu.:38.90
#  Median :25.00    Median : 58.00        Median :44.10
#  Mean   :25.55    Mean   : 58.05        Mean   :44.10
#  3rd Qu.:29.00    3rd Qu.: 63.00        3rd Qu.:49.17
#  Max.   :77.00    Max.   :109.00        Max.   :84.30
#
#  three_point_field_goals_made three_point_field_goals_attempted
#  Min.   : 0.000               Min.   : 2.00
#  1st Qu.: 5.000               1st Qu.:18.00
#  Median : 7.000               Median :22.00
#  Mean   : 7.508               Mean   :21.98
#  3rd Qu.: 9.000               3rd Qu.:26.00
#  Max.   :28.000               Max.   :74.00
#
#  three_point_field_goal_pct free_throws_made free_throws_attempted
#  Min.   : 0.00              Min.   : 0.00    Min.   : 0.00
#  1st Qu.:26.70              1st Qu.: 9.00    1st Qu.:13.00
#  Median :33.30              Median :12.00    Median :18.00
#  Mean   :34.02              Mean   :13.03    Mean   :18.35
#  3rd Qu.:41.20              3rd Qu.:17.00    3rd Qu.:23.00
#  Max.   :90.00              Max.   :50.00    Max.   :65.00
#
#  free_throw_pct   total_rebounds  offensive_rebounds defensive_rebounds
#  Min.   :  0.00   Min.   : 9.00   Min.   : 0.000     Min.   : 6.00
#  1st Qu.: 62.50   1st Qu.:30.00   1st Qu.: 7.000     1st Qu.:21.00
#  Median : 71.40   Median :35.00   Median :10.000     Median :25.00
#  Mean   : 70.67   Mean   :35.05   Mean   : 9.971     Mean   :25.08
#  3rd Qu.: 80.00   3rd Qu.:39.00   3rd Qu.:12.000     3rd Qu.:28.00
#  Max.   :100.00   Max.   :79.00   Max.   :51.000     Max.   :63.00
#
#  team_rebounds      assists          steals           blocks
#  Min.   :0       Min.   : 0.00   Min.   : 0.000   Min.   : 0.00
#  1st Qu.:0       1st Qu.:10.00   1st Qu.: 4.000   1st Qu.: 2.00
#  Median :0       Median :13.00   Median : 6.000   Median : 3.00
#  Mean   :0       Mean   :13.24   Mean   : 6.418   Mean   : 3.25
#  3rd Qu.:0       3rd Qu.:16.00   3rd Qu.: 8.000   3rd Qu.: 5.00
#  Max.   :0       Max.   :57.00   Max.   :37.000   Max.   :16.00
#  NA's   :12438
#    turnovers     team_turnovers    total_turnovers technical_fouls
#  Min.   : 1.00   Min.   : 0.0000   Min.   : 1.00   Min.   : 0.0000
#  1st Qu.:10.00   1st Qu.: 0.0000   1st Qu.:10.00   1st Qu.: 0.0000
#  Median :13.00   Median : 0.0000   Median :13.00   Median : 0.0000
#  Mean   :13.01   Mean   : 0.4838   Mean   :13.01   Mean   : 0.2094
#  3rd Qu.:16.00   3rd Qu.: 1.0000   3rd Qu.:16.00   3rd Qu.: 0.0000
#  Max.   :49.00   Max.   :30.0000   Max.   :49.00   Max.   :14.0000
#
#  total_technical_fouls flagrant_fouls          fouls       largest_lead
#  Min.   : 0.0000       Min.   :0.0000000   Min.   : 2.00   Length:56450
#  1st Qu.: 0.0000       1st Qu.:0.0000000   1st Qu.:14.00   Class :character
#  Median : 0.0000       Median :0.0000000   Median :17.00   Mode  :character
#  Mean   : 0.2094       Mean   :0.0002126   Mean   :17.37
#  3rd Qu.: 0.0000       3rd Qu.:0.0000000   3rd Qu.:20.00
#  Max.   :14.0000       Max.   :2.0000000   Max.   :42.00
#
#   home_away          opponent_id     opponent_name      opponent_mascot
#  Length:56450       Min.   :     1   Length:56450       Length:56450
#  Class :character   1st Qu.:   197   Class :character   Class :character
#  Mode  :character   Median :  2083   Mode  :character   Mode  :character
#                     Mean   :  2361
#                     3rd Qu.:  2466
#                     Max.   :127162
#
#  opponent_abbrev       game_id              season      season_type
#  Length:56450       Min.   :400986021   Min.   :2018   Min.   :2.000
#  Class :character   1st Qu.:401083542   1st Qu.:2019   1st Qu.:2.000
#  Mode  :character   Median :401262379   Median :2021   Median :2.000
#                     Mean   :401243226   Mean   :2021   Mean   :2.011
#                     3rd Qu.:401384951   3rd Qu.:2022   3rd Qu.:2.000
#                     Max.   :401532177   Max.   :2023   Max.   :3.000
#
#    game_date              team              School               ...1
#  Min.   :2017-11-10   Length:56450       Length:56450       Min.   :  0.0
#  1st Qu.:2018-11-25   Class :character   Class :character   1st Qu.: 66.0
#  Median :2021-01-23   Mode  :character   Mode  :character   Median :146.0
#  Mean   :2020-08-17                                         Mean   :156.6
#  3rd Qu.:2022-02-25                                         3rd Qu.:243.0
#  Max.   :2023-04-02                                         Max.   :362.0
#                                                             NA's   :18155
#      adj_o           adj_d         adj_tempo          luck
#  Min.   : 79.5   Min.   : 84.3   Min.   :58.20   Min.   :-0.192
#  1st Qu.:100.4   1st Qu.: 98.0   1st Qu.:65.90   1st Qu.:-0.039
#  Median :105.4   Median :102.9   Median :67.50   Median : 0.000
#  Mean   :105.4   Mean   :102.7   Mean   :67.66   Mean   : 0.000
#  3rd Qu.:110.2   3rd Qu.:107.6   3rd Qu.:69.30   3rd Qu.: 0.039
#  Max.   :127.4   Max.   :120.8   Max.   :82.50   Max.   : 0.194
#  NA's   :18155   NA's   :18155   NA's   :18155   NA's   :18155
#    sos_adj_o       sos_adj_d       OverallSOS        OverallSRS
#  Min.   : 90.9   Min.   : 92.2   Min.   :-16.950   Min.   :-38.170
#  1st Qu.:102.2   1st Qu.:100.9   1st Qu.: -4.660   1st Qu.: -6.960
#  Median :104.4   Median :104.0   Median : -1.520   Median : -0.640
#  Mean   :104.7   Mean   :103.4   Mean   :  0.081   Mean   :  0.039
#  3rd Qu.:107.3   3rd Qu.:106.2   3rd Qu.:  5.430   3rd Qu.:  6.880
#  Max.   :113.0   Max.   :111.0   Max.   : 13.890   Max.   : 27.790
#  NA's   :18155   NA's   :18155   NA's   :9538      NA's   :9538

# %%
head(select(teamgames, team))
#df %>% filter(!is.na(col1))
# summary(filter(teamgames, team=="Kansas"))
#select(filter(filter(teamgames, team=="Kansas"), is.na(sos_adj_d)), season, sos_adj_d)
# Out:
#   team
# 1 Northern Iowa
# 2 North Carolina
# 3 Pittsburgh
# 4 Navy
# 5 Georgia Tech
# 6 UCLA

# %%
teamstats <- teamgames %>% 
  group_by(team_short_display_name, season) %>%
  arrange(game_date) %>%
  mutate(
    team_score = ((field_goals_made - three_point_field_goals_made) * 2) + (three_point_field_goals_made * 3) + free_throws_made,
    possessions = (field_goals_attempted - offensive_rebounds + turnovers + (.475 * free_throws_attempted)),
    points_per_possession = (team_score / possessions),
    true_shooting_percentage = (team_score / (2 * (field_goals_attempted + (.44 * free_throws_attempted)))) * 100,
    free_throw_rate = (free_throws_attempted / field_goals_attempted),
    team_offensive_efficiency = (team_score/possessions) * 100,
    team_cm_points_per_possession = lag(cummean(points_per_possession), n = 1, default = 0),
    team_cm_true_shooting_percentage = lag(cummean(true_shooting_percentage), n = 1, default = 0),
    team_cm_free_throw_rate = lag(cummean(free_throw_rate), n = 1, default = 0),
    team_cm_offensive_efficiency = lag(cummean(team_offensive_efficiency), n = 1, default = 0),
  ) %>% 
  ungroup() %>% 
  rename(
    team_sos = OverallSOS,
    team_srs = OverallSRS
    )

teamstats <- teamstats %>% 
  select(game_id, team_id, team_offensive_efficiency) %>%
  mutate(team_id = as.numeric(team_id)) %>% 
  rename(opponent_id = team_id, 
         opponent_offensive_efficiency = team_offensive_efficiency) %>% 
  left_join(teamstats) %>%
  group_by(team_short_display_name, season) %>%
  arrange(game_date) %>%
  mutate(
    team_cm_defensive_efficiency = lag(cummean(opponent_offensive_efficiency), n = 1, default = 0)
    ) %>% 
  ungroup()

opponent <- teamstats %>% 
  select(game_id, team_id, offensive_rebounds, defensive_rebounds) %>% 
  rename(opponent_id = team_id, 
         opponent_offensive_rebounds = offensive_rebounds, 
         opponent_defensive_rebounds = defensive_rebounds) %>% 
  mutate(opponent_id = as.numeric(opponent_id))

newteamstats <- teamstats %>% 
  inner_join(opponent) %>% 
  mutate(
    orb_percentage = offensive_rebounds / (offensive_rebounds + opponent_defensive_rebounds),
    drb_percentage = defensive_rebounds / (opponent_offensive_rebounds + defensive_rebounds),
    team_cm_orb_percentage = lag(cummean(orb_percentage), n = 1, default = 0),
    team_cm_drb_percentage = lag(cummean(drb_percentage), n = 1, default = 0),
    steal_turnover_ratio = (steals / turnovers),
    team_cm_steal_turnover_ratio = lag(cummean(steal_turnover_ratio), n = 1, default = 0),
    net_efficiency = (team_offensive_efficiency - opponent_offensive_efficiency)
    )

team_side <- newteamstats %>%
  select(game_id, team_id, team_short_display_name, opponent_id, game_date, season, team_score, team_cm_points_per_possession, team_cm_true_shooting_percentage, team_cm_free_throw_rate, team_cm_orb_percentage, team_cm_drb_percentage, team_cm_steal_turnover_ratio, team_cm_offensive_efficiency, team_cm_defensive_efficiency, team_srs) %>% 
  na.omit()

opponent_side <- newteamstats %>%
  select(game_id, team_id, team_short_display_name, game_date, season, team_score, team_cm_points_per_possession, team_cm_true_shooting_percentage, team_cm_free_throw_rate, team_cm_orb_percentage, team_cm_drb_percentage, team_cm_steal_turnover_ratio, team_cm_offensive_efficiency, team_cm_defensive_efficiency, team_srs) %>% 
  na.omit() %>%
  rename(
    opponent_id = team_id,
    opponent_short_display_name = team_short_display_name,
    opponent_score = team_score,
    opponent_cm_points_per_possession = team_cm_points_per_possession,
    opponent_cm_true_shooting_percentage = team_cm_true_shooting_percentage,
    opponent_cm_free_throw_rate = team_cm_free_throw_rate,
    opponent_cm_orb_percentage = team_cm_orb_percentage,
    opponent_cm_drb_percentage = team_cm_drb_percentage,
    opponent_cm_offensive_efficiency = team_cm_offensive_efficiency,
    opponent_cm_defensive_efficiency = team_cm_defensive_efficiency,
    opponent_cm_steal_turnover_ratio = team_cm_steal_turnover_ratio,
    opponent_srs = team_srs
  ) %>%
  mutate(
    opponent_id = as.numeric(opponent_id)
    )

games <- team_side %>% 
  inner_join(opponent_side) %>% 
  mutate(
  TeamResult = as.factor(case_when(
    team_score > opponent_score ~ "W",
    opponent_score > team_score ~ "L"
))) %>% 
  na.omit()

games$TeamResult <- relevel(games$TeamResult, ref = "W")

cumulativemodelgames <- games %>% 
  select(game_id, game_date, team_short_display_name, opponent_short_display_name, season, team_cm_points_per_possession, team_cm_true_shooting_percentage, team_cm_free_throw_rate, team_cm_orb_percentage, team_cm_steal_turnover_ratio, team_cm_offensive_efficiency, team_cm_defensive_efficiency, team_srs, opponent_cm_points_per_possession, opponent_cm_true_shooting_percentage, opponent_cm_free_throw_rate, opponent_cm_orb_percentage, opponent_cm_steal_turnover_ratio, opponent_cm_offensive_efficiency, opponent_cm_defensive_efficiency, opponent_srs, TeamResult)
# Out:
# Joining with `by = join_by(game_id, opponent_id)`
# Joining with `by = join_by(game_id, opponent_id)`
# Joining with `by = join_by(game_id, opponent_id, game_date, season)`

# %%
summary(cumulativemodelgames)
# Out:
#     game_id            game_date          team_short_display_name
#  Min.   :400986021   Min.   :2017-11-10   Length:39554
#  1st Qu.:401082983   1st Qu.:2018-11-22   Class :character
#  Median :401258778   Median :2021-01-09   Mode  :character
#  Mean   :401232845   Mean   :2020-07-14
#  3rd Qu.:401376584   3rd Qu.:2022-02-19
#  Max.   :401531471   Max.   :2023-04-02
#  opponent_short_display_name     season     team_cm_points_per_possession
#  Length:39554                Min.   :2018   Min.   :0.0000
#  Class :character            1st Qu.:2019   1st Qu.:0.9895
#  Mode  :character            Median :2021   Median :1.0421
#                              Mean   :2021   Mean   :1.0140
#                              3rd Qu.:2022   3rd Qu.:1.0916
#                              Max.   :2023   Max.   :1.6692
#  team_cm_true_shooting_percentage team_cm_free_throw_rate
#  Min.   : 0.00                    Min.   :0.0000
#  1st Qu.:52.36                    1st Qu.:0.2858
#  Median :54.85                    Median :0.3273
#  Mean   :53.37                    Mean   :0.3246
#  3rd Qu.:57.15                    3rd Qu.:0.3711
#  Max.   :83.33                    Max.   :1.3750
#  team_cm_orb_percentage team_cm_steal_turnover_ratio
#  Min.   :0.0000         Min.   :0.0000
#  1st Qu.:0.2821         1st Qu.:0.5275
#  Median :0.2832         Median :0.5310
#  Mean   :0.2847         Mean   :0.5337
#  3rd Qu.:0.2862         3rd Qu.:0.5414
#  Max.   :0.4444         Max.   :0.7500
#  team_cm_offensive_efficiency team_cm_defensive_efficiency    team_srs
#  Min.   :  0.00               Min.   :  0.00               Min.   :-38.1700
#  1st Qu.: 98.95               1st Qu.: 94.52               1st Qu.: -6.7700
#  Median :104.21               Median : 99.51               Median : -0.0500
#  Mean   :101.40               Mean   : 96.60               Mean   :  0.4895
#  3rd Qu.:109.16               3rd Qu.:103.99               3rd Qu.:  7.7600
#  Max.   :166.92               Max.   :160.14               Max.   : 27.7900
#  opponent_cm_points_per_possession opponent_cm_true_shooting_percentage
#  Min.   :0.0000                    Min.   : 0.00
#  1st Qu.:0.9895                    1st Qu.:52.36
#  Median :1.0421                    Median :54.85
#  Mean   :1.0140                    Mean   :53.37
#  3rd Qu.:1.0916                    3rd Qu.:57.15
#  Max.   :1.6692                    Max.   :83.33
#  opponent_cm_free_throw_rate opponent_cm_orb_percentage
#  Min.   :0.0000              Min.   :0.0000
#  1st Qu.:0.2858              1st Qu.:0.2821
#  Median :0.3273              Median :0.2832
#  Mean   :0.3246              Mean   :0.2847
#  3rd Qu.:0.3711              3rd Qu.:0.2862
#  Max.   :1.3750              Max.   :0.4444
#  opponent_cm_steal_turnover_ratio opponent_cm_offensive_efficiency
#  Min.   :0.0000                   Min.   :  0.00
#  1st Qu.:0.5275                   1st Qu.: 98.95
#  Median :0.5310                   Median :104.21
#  Mean   :0.5337                   Mean   :101.40
#  3rd Qu.:0.5414                   3rd Qu.:109.16
#  Max.   :0.7500                   Max.   :166.92
#  opponent_cm_defensive_efficiency  opponent_srs      TeamResult
#  Min.   :  0.00                   Min.   :-38.1700   W:19777
#  1st Qu.: 94.52                   1st Qu.: -6.7700   L:19777
#  Median : 99.51                   Median : -0.0500
#  Mean   : 96.60                   Mean   :  0.4895
#  3rd Qu.:103.99                   3rd Qu.:  7.7600
#  Max.   :160.14                   Max.   : 27.7900

# %%
cumulative_split <- initial_split(cumulativemodelgames, prop = .8)
cumulative_train <- training(cumulative_split)
cumulative_test <- testing(cumulative_split)

# %%
cumulative_recipe <- 
  recipe(TeamResult ~ ., data = cumulative_train) %>% 
  update_role(game_id, game_date, team_short_display_name, opponent_short_display_name, season, new_role = "ID") %>%
  step_normalize(all_predictors())

summary(cumulative_recipe)
# Out:
#    variable                             type
# 1  game_id                              integer, numeric
# 2  game_date                            date
# 3  team_short_display_name              string   , unordered, nominal
# 4  opponent_short_display_name          string   , unordered, nominal
# 5  season                               double , numeric
# 6  team_cm_points_per_possession        double , numeric
# 7  team_cm_true_shooting_percentage     double , numeric
# 8  team_cm_free_throw_rate              double , numeric
# 9  team_cm_orb_percentage               double , numeric
# 10 team_cm_steal_turnover_ratio         double , numeric
# 11 team_cm_offensive_efficiency         double , numeric
# 12 team_cm_defensive_efficiency         double , numeric
# 13 team_srs                             double , numeric
# 14 opponent_cm_points_per_possession    double , numeric
# 15 opponent_cm_true_shooting_percentage double , numeric
# 16 opponent_cm_free_throw_rate          double , numeric
# 17 opponent_cm_orb_percentage           double , numeric
# 18 opponent_cm_steal_turnover_ratio     double , numeric
# 19 opponent_cm_offensive_efficiency     double , numeric
# 20 opponent_cm_defensive_efficiency     double , numeric
# 21 opponent_srs                         double , numeric
# 22 TeamResult                           factor   , unordered, nominal
#    role      source
# 1  ID        original
# 2  ID        original
# 3  ID        original
# 4  ID        original
# 5  ID        original
# 6  predictor original
# 7  predictor original
# 8  predictor original
# 9  predictor original
# 10 predictor original
# 11 predictor original
# 12 predictor original
# 13 predictor original
# 14 predictor original
# 15 predictor original
# 16 predictor original
# 17 predictor original
# 18 predictor original
# 19 predictor original
# 20 predictor original
# 21 predictor original
# 22 outcome   original

# %%
svm_mod <- 
  svm_poly() %>%
  set_engine("kernlab") %>%
  set_mode("classification")

# %%
svm_cumulative_workflow <- 
  workflow() %>% 
  add_model(svm_mod) %>% 
  add_recipe(cumulative_recipe)

# %%
svm_cumulative_fit <- 
  svm_cumulative_workflow %>% 
  fit(data = cumulative_train)

svmcumulativetrainresults <- cumulative_train %>%
  bind_cols(predict(svm_cumulative_fit, cumulative_train))

metrics(svmcumulativetrainresults, truth = TeamResult, estimate = .pred_class)
# Out:
#  Setting default kernel parameters
#   .metric  .estimator .estimate
# 1 accuracy binary     0.7160193
# 2 kap      binary     0.4320396

# %%
svmcumulativetestresults <- cumulative_test %>%
  bind_cols(predict(svm_cumulative_fit, cumulative_test))

metrics(svmcumulativetestresults, truth = TeamResult, estimate = .pred_class)
# Out:
#   .metric  .estimator .estimate
# 1 accuracy binary     0.7157123
# 2 kap      binary     0.4314136

# %%
teamstats <- teamgames %>% 
  group_by(team_short_display_name, season) %>%
  arrange(game_date) %>%
  mutate(
    team_score = ((field_goals_made - three_point_field_goals_made) * 2) + (three_point_field_goals_made * 3) + free_throws_made,
    possessions = (field_goals_attempted - offensive_rebounds + turnovers + (.475 * free_throws_attempted)),
    points_per_possession = (team_score / possessions),
    true_shooting_percentage = (team_score / (2 * (field_goals_attempted + (.44 * free_throws_attempted)))) * 100,
    free_throw_rate = (free_throws_attempted / field_goals_attempted),
    team_offensive_efficiency = (team_score/possessions) * 100,
    team_cm_points_per_possession = lag(cummean(points_per_possession), n = 1, default = 0),
    team_cm_true_shooting_percentage = lag(cummean(true_shooting_percentage), n = 1, default = 0),
    team_cm_free_throw_rate = lag(cummean(free_throw_rate), n = 1, default = 0),
    team_cm_offensive_efficiency = lag(cummean(team_offensive_efficiency), n = 1, default = 0),
  ) %>% 
  ungroup() %>% 
  rename(
    team_sos = OverallSOS,
    team_srs = OverallSRS
    )

teamstats <- teamstats %>% 
  select(game_id, team_id, team_offensive_efficiency) %>%
  mutate(team_id = as.numeric(team_id)) %>% 
  rename(opponent_id = team_id, 
         opponent_offensive_efficiency = team_offensive_efficiency) %>% 
  left_join(teamstats) %>%
  group_by(team_short_display_name, season) %>%
  arrange(game_date) %>%
  mutate(
    team_cm_defensive_efficiency = lag(cummean(opponent_offensive_efficiency), n = 1, default = 0)
    ) %>% 
  ungroup()

opponent <- teamstats %>% 
  select(game_id, team_id, offensive_rebounds, defensive_rebounds) %>% 
  rename(opponent_id = team_id, 
         opponent_offensive_rebounds = offensive_rebounds, 
         opponent_defensive_rebounds = defensive_rebounds) %>% 
  mutate(opponent_id = as.numeric(opponent_id))

newteamstats <- teamstats %>% 
  inner_join(opponent) %>% 
  mutate(
    orb_percentage = offensive_rebounds / (offensive_rebounds + opponent_defensive_rebounds),
    drb_percentage = defensive_rebounds / (opponent_offensive_rebounds + defensive_rebounds),
    team_cm_orb_percentage = lag(cummean(orb_percentage), n = 1, default = 0),
    team_cm_drb_percentage = lag(cummean(drb_percentage), n = 1, default = 0),
    steal_turnover_ratio = (steals / turnovers),
    team_cm_steal_turnover_ratio = lag(cummean(steal_turnover_ratio), n = 1, default = 0),
    net_efficiency = (team_offensive_efficiency - opponent_offensive_efficiency)
    )

team_side <- newteamstats %>%
  select(game_id, team_id, team_short_display_name, opponent_id, game_date, season, team_score, team_cm_points_per_possession, team_cm_true_shooting_percentage, team_cm_free_throw_rate, team_cm_orb_percentage, team_cm_drb_percentage, team_cm_steal_turnover_ratio, team_cm_offensive_efficiency, team_cm_defensive_efficiency, team_srs) %>% 
  na.omit()

opponent_side <- newteamstats %>%
  select(game_id, team_id, team_short_display_name, game_date, season, team_score, team_cm_points_per_possession, team_cm_true_shooting_percentage, team_cm_free_throw_rate, team_cm_orb_percentage, team_cm_drb_percentage, team_cm_steal_turnover_ratio, team_cm_offensive_efficiency, team_cm_defensive_efficiency, team_srs) %>% 
  na.omit() %>%
  rename(
    opponent_id = team_id,
    opponent_short_display_name = team_short_display_name,
    opponent_score = team_score,
    opponent_cm_points_per_possession = team_cm_points_per_possession,
    opponent_cm_true_shooting_percentage = team_cm_true_shooting_percentage,
    opponent_cm_free_throw_rate = team_cm_free_throw_rate,
    opponent_cm_orb_percentage = team_cm_orb_percentage,
    opponent_cm_drb_percentage = team_cm_drb_percentage,
    opponent_cm_offensive_efficiency = team_cm_offensive_efficiency,
    opponent_cm_defensive_efficiency = team_cm_defensive_efficiency,
    opponent_cm_steal_turnover_ratio = team_cm_steal_turnover_ratio,
    opponent_srs = team_srs
  ) %>%
  mutate(
    opponent_id = as.numeric(opponent_id)
    )

games <- team_side %>% 
  inner_join(opponent_side) %>% 
  mutate(
  TeamResult = as.factor(case_when(
    team_score > opponent_score ~ "W",
    opponent_score > team_score ~ "L"
))) %>% 
  na.omit()

games$TeamResult <- relevel(games$TeamResult, ref = "W")

cumulativemodelgames <- games %>% 
  select(game_id, game_date, team_short_display_name, opponent_short_display_name, season, team_cm_points_per_possession, team_cm_true_shooting_percentage, team_cm_free_throw_rate, team_cm_orb_percentage, team_cm_steal_turnover_ratio, team_cm_offensive_efficiency, team_cm_defensive_efficiency, team_srs, opponent_cm_points_per_possession, opponent_cm_true_shooting_percentage, opponent_cm_free_throw_rate, opponent_cm_orb_percentage, opponent_cm_steal_turnover_ratio, opponent_cm_offensive_efficiency, opponent_cm_defensive_efficiency, opponent_srs, TeamResult)
# Out:
# Joining with `by = join_by(game_id, opponent_id)`
# Joining with `by = join_by(game_id, opponent_id)`
# Joining with `by = join_by(game_id, opponent_id, game_date, season)`

# %%
filter(cumulativemodelgames, team_short_display_name=="Michigan State")
# Out:
#     game_id   game_date  team_short_display_name opponent_short_display_name
# 1   400986324 2017-11-11 Michigan State          North Florida
# 2   400986058 2017-11-15 Michigan State          Duke
# 3   400986367 2017-11-19 Michigan State          Stony Brook
# 4   400986381 2017-11-24 Michigan State          DePaul
# 5   400999748 2017-11-25 Michigan State          UConn
# 6   401001005 2017-11-27 Michigan State          North Carolina
# 7   400986109 2017-12-01 Michigan State          Notre Dame
# 8   400986399 2017-12-03 Michigan State          Nebraska
# 9   400986406 2017-12-06 Michigan State          Rutgers
# 10  400986423 2017-12-09 Michigan State          Southern Utah
# 11  400986438 2017-12-16 Michigan State          Oakland
# 12  400986445 2017-12-18 Michigan State          Houston Baptist
# 13  400986454 2017-12-22 Michigan State          Long Beach St
# 14  400986470 2017-12-29 Michigan State          Cleveland State
# 15  0.2905141                  0.5241832
# 16  0.2901924                  0.5249074
# 17  0.2902450                  0.5256687
# 18  0.2898208                  0.5259424
# 19  0.2892205                  0.5241531
# 20  0.2888834                  0.5230582
# 21  0.2890770                  0.5227483
# 22  0.2890406                  0.5224241
# 23  0.2889018                  0.5229870
# 24  0.2882507                  0.5233634
# 25  0.2882521                  0.5231504
# 26  0.2878782                  0.5239252
# 27  0.2875258                  0.5246827
# 28  0.2869739                  0.5255081
# 29  0.2865628                  0.5256009
# 30  0.2862035                  0.5268102
# ⋮   ⋮                          ⋮
# 134 0.2817740                  0.5448093
# 135 0.2818078                  0.5449382
# 136 0.2818345                  0.5449163
# 137 0.2819186                  0.5450424
# 138 0.2819751                  0.5452913
# 139 0.2819653                  0.5454367
# 140 0.2819988                  0.5456592
# 141 0.2820862                  0.5465881
# 142 0.2821298                  0.5468283
# 143 0.2821394                  0.5469786
# 144 0.2821664                  0.5471534
# 145 0.2821532                  0.5473150
# 146 0.2821464                  0.5475196
# 147 0.2821725                  0.5476055
# 148 0.2821642                  0.5476837
# 149 0.2820956                  0.5477979
# 150 0.2820974                  0.5479164
# 151 0.2820769                  0.5480384
# 152 0.2820153                  0.5482592
# 153 0.2820238                  0.5482634
# 154 0.2819507                  0.5484021
# 155 0.2818825                  0.5489411
# 156 0.2818998                  0.5489228
# 157 0.2818436                  0.5492506
# 158 0.2818250                  0.5494885
# 159 0.2818149                  0.5497251
# 160 0.2818536                  0.5499185
# 161 0.2818509                  0.5500893
# 162 0.2818572                  0.5500898
# 163 0.2818632                  0.5501303
#     opponent_cm_offensive_efficiency opponent_cm_defensive_efficiency
# 1     0.00000                          0.00000
# 2   127.02800                         90.20380
# 3    93.04685                        108.78116
# 4    99.03615                        100.55616
# 5   105.45753                         88.14670
# 6   118.08923                         95.59028
# 7   127.04016                         91.40440
# 8   107.88037                         97.71173
# 9   103.26848                         79.46671
# 10  109.66468                        107.95332
# 11  103.83051                        104.06116
# 12  107.76930                        106.89549
# 13  102.17896                        111.96752
# 14   96.30196                        101.57801
# 15  112.33171                         90.54210
# 16  111.19004                         96.70321
# 17  100.57577                         86.72497
# 18  113.77811                         93.05600
# 19  107.97335                        102.36891
# 20  105.07591                         97.46703
# 21  105.45106                        101.55381
# 22  110.90131                         97.01394
# 23  108.28393                         94.46859
# 24  105.39433                        104.02272
# 25  111.46569                        108.03449
# 26  119.14960                         93.40638
# 27  106.93452                        104.57217
# 28  103.40456                         99.44201
# 29  104.30769                        100.63144
# 30  105.07329                        103.26483
# ⋮   ⋮                                ⋮
# 134 115.70803                         78.81365
# 135  98.96256                         93.56321
# 136 109.77423                         97.90275
# 137 113.73350                        107.35731
# 138  95.96927                         85.83973
# 139 112.64221                         97.78403
# 140  95.99417                         93.66511
# 141 101.38758                        112.27731
# 142 103.81344                         98.79066
# 143 101.17171                         94.74622
# 144 108.45232                         98.81187
# 145 103.17152                         94.06482
# 146 107.15054                         89.47059
# 147 117.46187                         93.44748
# 148 104.07243                         84.71830
# 149 111.25405                         95.48878
# 150 113.61780                        102.29135
# 151 114.70676                         93.00142
# 152 104.65349                         86.89735
# 153 108.15145                         95.18555
# 154 110.81651                        100.00032
# 155 106.16383                        100.96572
# 156 109.39276                         97.47274
# 157 112.09550                        104.21490
# 158  99.45279                        100.74208
# 159 109.38561                        103.19104
# 160 109.77150                        103.71994
# 161 105.23293                         98.38229
# 162 113.89219                         99.71972
# 163 105.21153                         96.02576
#     opponent_srs TeamResult
# 1   -11.40       W
# 2    24.44       L
# 3    -5.09       W
# 4     6.55       W
# 5     1.08       W
# 6    20.08       W
# 7    13.65       W
# 8    10.99       W
# 9     5.50       W
# 10   -7.64       W
# 11   -1.82       W
# 12  -16.14       W
# 13   -3.75       W
# 14  -10.82       W
# 15   13.78       W
# 16   17.67       L
# 17    5.50       W
# 18   19.03       L
# 19    9.89       W
# 20    8.50       W
# 21   10.38       W
# 22   13.78       W
# 23   15.85       W
# 24    9.89       W
# 25    8.13       W
# 26   23.41       W
# 27    7.01       W
# 28    9.63       W
# 29    8.50       W
# 30   10.38       W
# ⋮   ⋮            ⋮
# 134 17.23        L
# 135  6.56        W
# 136  6.39        W
# 137  0.63        L
# 138  1.86        L
# 139  7.11        W
# 140 -2.30        W
# 141  0.13        W
# 142  3.73        W
# 143  1.89        W
# 144  7.78        W
# 145  0.03        W
# 146  8.64        L
# 147  6.26        L
# 148  1.30        W
# 149  8.57        L
# 150 15.18        W
# 151  6.26        L
# 152  1.30        L
# 153  3.70        W
# 154  7.59        W
# 155  7.78        L
# 156  8.57        W
# 157 15.18        L
# 158  1.89        W
# 159  7.59        W
# 160  7.59        L
# 161  7.37        W
# 162 12.37        W
# 163 10.32        L

# %% [markdown]
# EXPERIMENT TO SEE IF I CAN RUN PROOGRAM ON A MAP OF ALL GAMES ON A CERTAIN DAY
#
# ---

# %%
# improvement below

run_model <- function(team1, team2){

  championshipgame <- tibble(
  team_short_display_name=team1,
  opponent_short_display_name=team2
  )

  championshipgame <- cumulativemodelgames %>% 
  group_by(team_short_display_name) %>% 
  filter(game_date == max(game_date) & season == 2023) %>% 
  select(-TeamResult, -starts_with("opponent")) %>% 
  right_join(championshipgame, multiple = "all")

  championshipgame <- cumulativemodelgames %>% 
    group_by(opponent_short_display_name) %>% 
    filter(game_date == max(game_date) & season == 2023) %>% 
    ungroup() %>% 
    select(-TeamResult, -starts_with("team"), -game_id, -game_date, -season) %>% right_join(championshipgame)

  championship <- svm_cumulative_fit %>% 
    predict(new_data = championshipgame) %>%
    bind_cols(championshipgame) %>% 
    select(.pred_class, team_short_display_name, opponent_short_display_name, everything())

  return(championship)
}


df1 <- run_model("San Diego State", "UConn")
# Out:
# Joining with `by = join_by(team_short_display_name)`
# Joining with `by = join_by(opponent_short_display_name)`

# %%
df1
# Out:
#   .pred_class team_short_display_name opponent_short_display_name
# 1 L           San Diego State         UConn
#   opponent_cm_points_per_possession opponent_cm_true_shooting_percentage
# 1 1.147967                          57.93194
#   opponent_cm_free_throw_rate opponent_cm_orb_percentage
# 1 0.3116656                   0.2818681
#   opponent_cm_steal_turnover_ratio opponent_cm_offensive_efficiency
# 1 0.5501345                        114.7967
#   opponent_cm_defensive_efficiency ⋯ game_date  season
# 1 94.402                           ⋯ 2023-04-01 2023
#   team_cm_points_per_possession team_cm_true_shooting_percentage
# 1 1.062447                      54.34687
#   team_cm_free_throw_rate team_cm_orb_percentage team_cm_steal_turnover_ratio
# 1 0.3297653               0.2818679              0.5501368
#   team_cm_offensive_efficiency team_cm_defensive_efficiency team_srs
# 1 106.2447                     94.13969                     3.99

# %%
df <- data.frame(Column1 = c('Value 1', 'Value 2', 'Value 3'),
                 Column2 = c('Value 1', 'Value 2', 'Value 3'))

# %%
account_endpoint <- "https://blakestorageaccount581.blob.core.windows.net"
account_key <- "nkkvw1xse99lhH2Cdf89T3PXbRpy/UAhdifhBddYew0QLOvcl8e2m/zMICpkFJt7+RufBQPgySLC+AStHxZGbQ=="
container_name <- "model-csv-files"
bl_endp_key <- storage_endpoint(account_endpoint, key=account_key)
cont <- storage_container(bl_endp_key, container_name)
write.csv(df1, "model_pred3.csv",row.names = FALSE)
upload_blob(cont, src="model_pred3.csv", dest="model_pred4.csv")

# %%
run_model <- function(team1, team2){

  championshipgame <- tibble(
  team_short_display_name=team1,
  opponent_short_display_name=team2
  )

  championshipgame <- cumulativemodelgames %>% 
  group_by(team_short_display_name) %>% 
  filter(game_date == max(game_date) & season == 2023) %>% 
  select(-TeamResult, -starts_with("opponent")) %>% 
  right_join(championshipgame)

  championshipgame <- cumulativemodelgames %>% 
    group_by(opponent_short_display_name) %>% 
    filter(game_date == max(game_date) & season == 2023) %>% 
    ungroup() %>% 
    select(-TeamResult, -starts_with("team"), -game_id, -game_date, -season) %>% right_join(championshipgame)

  championship <- svm_cumulative_fit %>% 
    predict(new_data = championshipgame) %>%
    bind_cols(championshipgame) %>% 
    select(.pred_class, team_short_display_name, opponent_short_display_name, everything())
    
  return(championship)
}

# %%
df1 <- run_model("Kansas State", "Michigan State")
df2 <- run_model("FAU", "Tennessee")
df4 <- run_model("UConn", "Arkansas")
df3 <- run_model("UCLA", "Gonzaga")
df5 <- run_model("Alabama", "San Diego State")
df6 <- run_model("Creighton", "Princeton")
df7 <- run_model("Houston", "Miami")
df8 <- run_model("Texas", "Xavier")

df9 <- rbind(df1,df2)
df10 <- rbind(df9, df4)
df11 <- rbind(df10, df3)
df12 <- rbind(df11, df5)
df13 <- rbind(df12, df6)
df14 <- rbind(df13, df7)
df15 <- rbind(df14, df8)
df15

write.csv(df15, "model_pred.csv")

# %%
to_azure <- function(frame) { 
  bl <- storage_endpoint("https://blakestorageaccount581.blob.core.windows.net/model-csv-files?sp=r&st=2023-03-21T23:01:30Z&se=2023-03-22T07:01:30Z&spr=https&sv=2021-12-02&sr=c&sig=dkOCMgDHRxCN92KtGSXHA4sd%2Bysd2ISlcgd2Dd5Qdu8%3D", key="sp=r&st=2023-03-21T23:01:30Z&se=2023-03-22T07:01:30Z&spr=https&sv=2021-12-02&sr=c&sig=dkOCMgDHRxCN92KtGSXHA4sd%2Bysd2ISlcgd2Dd5Qdu8%3D")
  container <- storage_container(bl, "model-csv-files")
  write.csv(frame, "File.csv")
  storage_write_csv(frame, cont, "test.csv")
}


to_azure(Date_Frame)
